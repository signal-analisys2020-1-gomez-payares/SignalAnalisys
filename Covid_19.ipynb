# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as pyplot

# %%
date=pd.read_csv('Casos_positivos_de_COVID-19_en_Colombia.csv')
# Out:
# C:\Users\alexp\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (14,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
date.head()
# Out:
#    ID de caso    Fecha de notificación  Codigo DIVIPOLA  Ciudad de ubicación  \
# 0           1  2020-03-02T00:00:00.000            11001          Bogotá D.C.
# 1           2  2020-03-06T00:00:00.000            76111  Guadalajara de Buga
# 2           3  2020-03-07T00:00:00.000             5001             Medellín
# 3           4  2020-03-09T00:00:00.000             5001             Medellín
# 4           5  2020-03-09T00:00:00.000             5001             Medellín
#
#   Departamento o Distrito     atención  Edad Sexo         Tipo Estado  \
# 0              Bogotá D.C.  Recuperado    19    F    Importado   Leve
# 1          Valle del Cauca  Recuperado    34    M    Importado   Leve
# 2                Antioquia  Recuperado    50    F    Importado   Leve
# 3                Antioquia  Recuperado    55    M  Relacionado   Leve
# 4                Antioquia  Recuperado    25    M  Relacionado   Leve
#
#   País de procedencia                      FIS Fecha de muerte  \
# ...

# %%
covid19 =pd.DataFrame(data=date)

# %%
covid19[['Sexo','Edad' ,'Ciudad de ubicación']]
# Out:
#       Sexo  Edad  Ciudad de ubicación
# 0        F    19          Bogotá D.C.
# 1        M    34  Guadalajara de Buga
# 2        F    50             Medellín
# 3        M    55             Medellín
# 4        M    25             Medellín
# ...    ...   ...                  ...
# 33349    F    78             Montería
# 33350    F    19             Montería
# 33351    F    27             Montería
# 33352    M    50             Montería
# 33353    F    30             Montería
#
# [33354 rows x 3 columns]

# %%
list(covid19.columns)
# Out:
# ['ID de caso',
#  'Fecha de notificación',
#  'Codigo DIVIPOLA',
#  'Ciudad de ubicación',
#  'Departamento o Distrito ',
#  'atención',
#  'Edad',
#  'Sexo',
#  'Tipo',
#  'Estado',
#  'País de procedencia',
#  'FIS',
#  'Fecha de muerte',
#  'Fecha diagnostico',
#  'Fecha recuperado',
#  'fecha reporte web',
#  'Tipo recuperación']

# %%
covid19_sexo=covid19['Sexo']

# %%
covid19_sexo.shape
# Out:
# (33354,)

# %%
covid19_ubicacion=covid19['Ciudad de ubicación']

# %%
plt.plot(covid19_sexo,covid19_ubicacion,label ='linea')
plt.title("covid19")
plt.show()

# %%
plt.plot(covid19_ubicacion)

# %%
covid19_estado=covid19['Estado']

# %%
covid19_atencion=covid19['atención']

# %%
covid19_fecha_diagnostico=covid19['Fecha diagnostico']

# %%
covid19_fecha_de_muerte=covid19['Fecha de muerte']

# %%
covid_19_fecha_recuperados=covid19['Fecha recuperado']

# %%
plt.plot(covid19_sexo,covid19_ubicacion,covid19_fecha_diagnostico)
plt.title("covid19 - genero-ubicacion-fecha diagnostico")
plt.show()

# %%
plt.plot(covid19_sexo,covid19_ubicacion,covid19_fecha_diagnostico)
plt.title("covid19 - genero-ubicacion-fecha diagnostico")
plt.show()
